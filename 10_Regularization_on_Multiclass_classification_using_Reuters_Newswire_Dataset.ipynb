# %% [markdown]
# <a href="https://colab.research.google.com/github/20NN1A05F5/SOC_V/blob/main/10_Regularization_on_Multiclass_classification_using_Reuters_Newswire_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from keras.datasets import reuters

# %%
(train_X, train_Y), (test_X, test_Y) = reuters.load_data(num_words=10000)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/reuters.npz
# 2110848/2110848 [==============================] - 0s 0us/step

# %%
import numpy as np
from keras.utils import to_categorical
def OneHotEncoding_fn(ReutersData, dimension=10000):
  OneHotEncoded_Data = np.zeros((len(ReutersData), dimension))
  for i, sequence in enumerate(ReutersData):
      OneHotEncoded_Data[i, sequence] = 1.
  return OneHotEncoded_Data
x_train = OneHotEncoding_fn(train_X)
x_test = OneHotEncoding_fn(test_X)

y_train = to_categorical(train_Y)
y_test = to_categorical(test_Y)

# %%
from keras import models
from keras import layers
from keras import regularizers
model = models.Sequential()
model.add(layers.Dense(64, kernel_regularizer=regularizers.l1_l2(l1=0.001, l2=0.01), activation='relu', input_shape=(10000,)))
model.add(layers.Dense(64, kernel_regularizer=regularizers.l1_l2(l1=0.001, l2=0.01), activation='relu'))
model.add(layers.Dense(46, activation='softmax'))

# %%
from keras import optimizers
from keras import losses
from keras import metrics
X_validation = x_train[:800]
X_train_without_val = x_train[800:]
y_validation = y_train[:800]
y_train_without_val = y_train[800:]
model.compile(optimizer=optimizers.RMSprop(learning_rate=0.001, rho=0.9),
             loss=losses.categorical_crossentropy,
             metrics=[metrics.categorical_accuracy])
history = model.fit(X_train_without_val,
                    y_train_without_val,
                    epochs=25,
                    batch_size=512,
                    validation_data=(X_validation,y_validation))
# Out:
# Epoch 1/25
# 16/16 [==============================] - 2s 86ms/step - loss: 7.2071 - categorical_accuracy: 0.4677 - val_loss: 3.7229 - val_categorical_accuracy: 0.5462
# Epoch 2/25
# 16/16 [==============================] - 1s 64ms/step - loss: 3.4018 - categorical_accuracy: 0.5406 - val_loss: 3.1130 - val_categorical_accuracy: 0.5600
# Epoch 3/25
# 16/16 [==============================] - 1s 65ms/step - loss: 3.0473 - categorical_accuracy: 0.5917 - val_loss: 2.8763 - val_categorical_accuracy: 0.6175
# Epoch 4/25
# 16/16 [==============================] - 1s 77ms/step - loss: 2.8524 - categorical_accuracy: 0.6404 - val_loss: 2.7291 - val_categorical_accuracy: 0.6450
# Epoch 5/25
# 16/16 [==============================] - 1s 92ms/step - loss: 2.7029 - categorical_accuracy: 0.6594 - val_loss: 2.6082 - val_categorical_accuracy: 0.6575
# Epoch 6/25
# 16/16 [==============================] - 1s 64ms/step - loss: 2.5892 - categorical_accuracy: 0.6649 - val_loss: 2.4902 - val_categorical_accuracy: 0.6787
# Epoch 7/25
# 16/16 [==============================] - 1s 69ms/step - loss: 2.4891 - categorical_accuracy: 0.6750 - val_loss: 2.4209 - val_categorical_accuracy: 0.6662
# Epoch 8/25
# 16/16 [==============================] - 2s 96ms/step - loss: 2.4113 - categorical_accuracy: 0.6772 - val_loss: 2.3367 - val_categorical_accuracy: 0.6862
# Epoch 9/25
# 16/16 [==============================] - 1s 85ms/step - loss: 2.3423 - categorical_accuracy: 0.6827 - val_loss: 2.2758 - val_categorical_accuracy: 0.6862
# Epoch 10/25
# 16/16 [==============================] - 1s 53ms/step - loss: 2.2754 - categorical_accuracy: 0.6888 - val_loss: 2.2615 - val_categorical_accuracy: 0.6888
# Epoch 11/25
# 16/16 [==============================] - 1s 57ms/step - loss: 2.2340 - categorical_accuracy: 0.6891 - val_loss: 2.1741 - val_categorical_accuracy: 0.6925
# Epoch 12/25
# 16/16 [==============================] - 1s 65ms/step - loss: 2.1942 - categorical_accuracy: 0.6893 - val_loss: 2.1610 - val_categorical_accuracy: 0.6900
# Epoch 13/25
# 16/16 [==============================] - 1s 63ms/step - loss: 2.1559 - categorical_accuracy: 0.6910 - val_loss: 2.1062 - val_categorical_accuracy: 0.6938
# Epoch 14/25
# 16/16 [==============================] - 1s 66ms/step - loss: 2.1205 - categorical_accuracy: 0.6959 - val_loss: 2.0850 - val_categorical_accuracy: 0.6938
# Epoch 15/25
# 16/16 [==============================] - 1s 62ms/step - loss: 2.1007 - categorical_accuracy: 0.6926 - val_loss: 2.0555 - val_categorical_accuracy: 0.6963
# Epoch 16/25
# 16/16 [==============================] - 1s 60ms/step - loss: 2.0736 - categorical_accuracy: 0.6954 - val_loss: 2.0311 - val_categorical_accuracy: 0.6950
# Epoch 17/25
# 16/16 [==============================] - 1s 53ms/step - loss: 2.0497 - categorical_accuracy: 0.6998 - val_loss: 2.0190 - val_categorical_accuracy: 0.7000
# Epoch 18/25
# 16/16 [==============================] - 1s 52ms/step - loss: 2.0297 - categorical_accuracy: 0.6984 - val_loss: 2.0048 - val_categorical_accuracy: 0.7025
# Epoch 19/25
# 16/16 [==============================] - 1s 63ms/step - loss: 2.0133 - categorical_accuracy: 0.6964 - val_loss: 1.9794 - val_categorical_accuracy: 0.6988
# Epoch 20/25
# 16/16 [==============================] - 1s 68ms/step - loss: 1.9893 - categorical_accuracy: 0.7028 - val_loss: 1.9765 - val_categorical_accuracy: 0.6938
# Epoch 21/25
# 16/16 [==============================] - 1s 88ms/step - loss: 1.9797 - categorical_accuracy: 0.7020 - val_loss: 1.9432 - val_categorical_accuracy: 0.7000
# Epoch 22/25
# 16/16 [==============================] - 1s 82ms/step - loss: 1.9620 - categorical_accuracy: 0.6986 - val_loss: 1.9386 - val_categorical_accuracy: 0.7025
# Epoch 23/25
# 16/16 [==============================] - 1s 57ms/step - loss: 1.9467 - categorical_accuracy: 0.7046 - val_loss: 1.9349 - val_categorical_accuracy: 0.7025
# Epoch 24/25
# 16/16 [==============================] - 1s 51ms/step - loss: 1.9351 - categorical_accuracy: 0.7052 - val_loss: 1.9135 - val_categorical_accuracy: 0.7038
# Epoch 25/25
# 16/16 [==============================] - 1s 48ms/step - loss: 1.9168 - categorical_accuracy: 0.7073 - val_loss: 1.9027 - val_categorical_accuracy: 0.7075

# %%
import matplotlib.pyplot as plt

history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']

epochs = range(1, len(loss_values) + 1)

plt.plot(epochs, loss_values, 'g--', label='Training loss')
plt.plot(epochs, val_loss_values, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
plt.clf()
acc_values = history_dict['categorical_accuracy']
val_acc_values = history_dict['val_categorical_accuracy']
plt.plot(epochs, acc_values, 'g--', label='Training Accuracy')
plt.plot(epochs, val_acc_values, 'r', label='Validation Accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

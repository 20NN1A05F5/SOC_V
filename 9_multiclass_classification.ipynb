# %% [markdown]
# <a href="https://colab.research.google.com/github/20NN1A05F5/SOC_V/blob/main/9_multiclass_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np

# %%
from keras.datasets import reuters

# %%
(train_X, train_Y), (test_X, test_Y) = reuters.load_data(num_words=10000)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/reuters.npz
# 2110848/2110848 [==============================] - 0s 0us/step

# %%
import numpy as np
from keras.utils import to_categorical

def OneHotEncoding_fn(ReutersData, dimension=10000):
    # 8982 x 10k matrix of zeros
    OneHotEncoded_Data = np.zeros((len(ReutersData), dimension))
    for i, sequence in enumerate(ReutersData):
        #Selectively make indices as 1 based on availability of word in the review.
        OneHotEncoded_Data[i, sequence] = 1.
    return OneHotEncoded_Data

x_train = OneHotEncoding_fn(train_X)
x_test = OneHotEncoding_fn(test_X)

y_train = to_categorical(train_Y)
y_test = to_categorical(test_Y)

# %%
from keras import models
from keras import layers

model = models.Sequential()
model.add(layers.Dense(64, activation='relu', input_shape=(10000,)))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(46, activation='softmax'))

# %%
from keras import optimizers
from keras import losses
from keras import metrics

X_validation = x_train[:800]
X_train_without_val = x_train[800:]
y_validation = y_train[:800]
y_train_without_val = y_train[800:]


model.compile(optimizer=optimizers.RMSprop(learning_rate=0.001, rho=0.9),
             loss=losses.categorical_crossentropy,
             metrics=[metrics.categorical_accuracy])

history = model.fit(X_train_without_val,
                    y_train_without_val,
                    epochs=25,
                    batch_size=512,
                    validation_data=(X_validation,y_validation))
# Out:
# Epoch 1/25
# 16/16 [==============================] - 3s 111ms/step - loss: 2.4532 - categorical_accuracy: 0.4993 - val_loss: 1.6300 - val_categorical_accuracy: 0.6388
# Epoch 2/25
# 16/16 [==============================] - 1s 48ms/step - loss: 1.4138 - categorical_accuracy: 0.6937 - val_loss: 1.2782 - val_categorical_accuracy: 0.7225
# Epoch 3/25
# 16/16 [==============================] - 1s 49ms/step - loss: 1.1054 - categorical_accuracy: 0.7509 - val_loss: 1.1496 - val_categorical_accuracy: 0.7450
# Epoch 4/25
# 16/16 [==============================] - 1s 49ms/step - loss: 0.9044 - categorical_accuracy: 0.7982 - val_loss: 1.0359 - val_categorical_accuracy: 0.7725
# Epoch 5/25
# 16/16 [==============================] - 1s 49ms/step - loss: 0.7436 - categorical_accuracy: 0.8377 - val_loss: 0.9850 - val_categorical_accuracy: 0.7900
# Epoch 6/25
# 16/16 [==============================] - 1s 67ms/step - loss: 0.6158 - categorical_accuracy: 0.8702 - val_loss: 0.9283 - val_categorical_accuracy: 0.8000
# Epoch 7/25
# 16/16 [==============================] - 1s 85ms/step - loss: 0.5106 - categorical_accuracy: 0.8911 - val_loss: 0.8939 - val_categorical_accuracy: 0.8100
# Epoch 8/25
# 16/16 [==============================] - 1s 74ms/step - loss: 0.4240 - categorical_accuracy: 0.9085 - val_loss: 0.8601 - val_categorical_accuracy: 0.8150
# Epoch 9/25
# 16/16 [==============================] - 1s 51ms/step - loss: 0.3598 - categorical_accuracy: 0.9206 - val_loss: 0.8577 - val_categorical_accuracy: 0.8100
# Epoch 10/25
# 16/16 [==============================] - 1s 49ms/step - loss: 0.3048 - categorical_accuracy: 0.9322 - val_loss: 0.8512 - val_categorical_accuracy: 0.8150
# Epoch 11/25
# 16/16 [==============================] - 1s 50ms/step - loss: 0.2648 - categorical_accuracy: 0.9400 - val_loss: 0.8841 - val_categorical_accuracy: 0.8000
# Epoch 12/25
# 16/16 [==============================] - 1s 48ms/step - loss: 0.2323 - categorical_accuracy: 0.9454 - val_loss: 0.8603 - val_categorical_accuracy: 0.8087
# Epoch 13/25
# 16/16 [==============================] - 1s 50ms/step - loss: 0.2063 - categorical_accuracy: 0.9477 - val_loss: 0.8762 - val_categorical_accuracy: 0.8263
# Epoch 14/25
# 16/16 [==============================] - 1s 49ms/step - loss: 0.1851 - categorical_accuracy: 0.9522 - val_loss: 0.8854 - val_categorical_accuracy: 0.8138
# Epoch 15/25
# 16/16 [==============================] - 1s 49ms/step - loss: 0.1709 - categorical_accuracy: 0.9515 - val_loss: 0.8804 - val_categorical_accuracy: 0.8263
# Epoch 16/25
# 16/16 [==============================] - 1s 51ms/step - loss: 0.1579 - categorical_accuracy: 0.9536 - val_loss: 0.9090 - val_categorical_accuracy: 0.8138
# Epoch 17/25
# 16/16 [==============================] - 1s 50ms/step - loss: 0.1494 - categorical_accuracy: 0.9555 - val_loss: 0.9156 - val_categorical_accuracy: 0.8138
# Epoch 18/25
# 16/16 [==============================] - 1s 48ms/step - loss: 0.1428 - categorical_accuracy: 0.9559 - val_loss: 0.9619 - val_categorical_accuracy: 0.8062
# Epoch 19/25
# 16/16 [==============================] - 1s 48ms/step - loss: 0.1319 - categorical_accuracy: 0.9572 - val_loss: 0.9379 - val_categorical_accuracy: 0.8075
# Epoch 20/25
# 16/16 [==============================] - 1s 50ms/step - loss: 0.1309 - categorical_accuracy: 0.9564 - val_loss: 0.9491 - val_categorical_accuracy: 0.8150
# Epoch 21/25
# 16/16 [==============================] - 1s 69ms/step - loss: 0.1222 - categorical_accuracy: 0.9573 - val_loss: 0.9815 - val_categorical_accuracy: 0.8062
# Epoch 22/25
# 16/16 [==============================] - 1s 83ms/step - loss: 0.1223 - categorical_accuracy: 0.9544 - val_loss: 1.0430 - val_categorical_accuracy: 0.7987
# Epoch 23/25
# 16/16 [==============================] - 1s 72ms/step - loss: 0.1208 - categorical_accuracy: 0.9576 - val_loss: 0.9627 - val_categorical_accuracy: 0.8138
# Epoch 24/25
# 16/16 [==============================] - 1s 49ms/step - loss: 0.1137 - categorical_accuracy: 0.9595 - val_loss: 0.9908 - val_categorical_accuracy: 0.8100
# Epoch 25/25
# 16/16 [==============================] - 1s 50ms/step - loss: 0.1122 - categorical_accuracy: 0.9572 - val_loss: 0.9818 - val_categorical_accuracy: 0.8112

# %%
import matplotlib.pyplot as plt

history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']

epochs = range(1, len(loss_values) + 1)

plt.plot(epochs, loss_values, 'g--', label='Training loss')
plt.plot(epochs, val_loss_values, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
plt.clf()
acc_values = history_dict['categorical_accuracy']
val_acc_values = history_dict['val_categorical_accuracy']
plt.plot(epochs, acc_values, 'g--', label='Training Accuracy')
plt.plot(epochs, val_acc_values, 'r', label='Validation Accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
